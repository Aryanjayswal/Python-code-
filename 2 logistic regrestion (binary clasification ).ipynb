# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\ED pandas\placement-dataset.csv")

# %%
df
# Out:
#     cgpa   iq  placement
# 0    6.8  123          1
# 1    5.9  106          0
# 2    5.3  121          0
# 3    7.4  132          1
# 4    5.8  142          0
# ..   ...  ...        ...
# 95   4.3  200          0
# 96   4.4   42          0
# 97   6.7  182          1
# 98   6.3  103          1
# 99   6.2  113          1
#
# [100 rows x 3 columns]

# %%
sns.scatterplot(data=df,x="cgpa",y="iq",hue="placement")
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
x= df.iloc[:,:-1]
y = df["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(x_test,y_test)
# Out:
# LogisticRegression()

# %% [markdown]
# LogisticRegression()
# In a Jupyter environment, please rerun this cell to show the HTML representation or trust the notebook.
# On GitHub, the HTML representation is unable to render, please try loading this page with nbviewer.org.

# %%
lr.score(x_test,y_test)*100
# Out:
# 100.0

# %%
lr.predict([[6.8,102]])
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
lr.coef_
# Out:
# array([[ 1.81018109, -0.03241522]])

# %%
lr.intercept_
# Out:
# array([-7.14555998])

# %%
# to create  a desition Boundry

# %%
# to create decision Boundaries
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=lr)
plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
